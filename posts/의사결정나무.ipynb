# %% [raw]
# ---
# title: "의사결정나무"
# author: "최규빈"
# date: "10/05/2023"
# bibliography: ref.bib
# draft: true
# ---

# %%
import pandas as pd
import sklearn.tree

# %%
df = pd.read_csv('employment.csv')
df
# Out:
#      toeic       gpa  employment
# 0      135  0.051535           0
# 1      935  0.355496           0
# 2      485  2.228435           0
# 3       65  1.179701           0
# 4      445  3.962356           1
# ..     ...       ...         ...
# 495    280  4.288465           1
# 496    310  2.601212           1
# 497    225  0.042323           0
# 498    320  1.041416           0
# 499    375  3.626883           1
#
# [500 rows x 3 columns]

# %%
X, XX, y, yy = sklearn.model_selection.train_test_split(df.drop('employment',axis=1),df[['employment']],random_state=42)

# %%
predictr = sklearn.tree.DecisionTreeClassifier()
predictr
# Out:
# DecisionTreeClassifier()

# %%
predictr.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
predictr.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt

# %%
sklearn.tree.plot_tree(predictr, max_depth=2)
fig = plt.gcf()

# %%
fig.set_dpi(200)

# %%
fig
