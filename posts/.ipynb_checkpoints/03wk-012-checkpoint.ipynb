# %% [raw]
# ---
# title: "03wk-012: 취업, 로지스틱"
# author: "최규빈"
# date: "09/21/2023"
# bibliography: ref.bib
# ---

# %% [markdown]
# # 1. 강의영상

# %% [markdown]
# # 2. Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. 토익, GPA

# %%
toeic = np.random.randint(1,200,size=500)*5
gpa = np.random.uniform(0,4.5,size=500)

# %%
y = np.random.binomial(1,prob,size=500)

# %%
df = pd.DataFrame({'toeic':toeic,'gpa':gpa,'employment':y})
df.to_csv('
# Out:
#      toeic       gpa  y
# 0      135  0.051535  0
# 1      935  0.355496  0
# 2      485  2.228435  0
# 3       65  1.179701  0
# 4      445  3.962356  1
# ..     ...       ... ..
# 495    280  4.288465  1
# 496    310  2.601212  1
# 497    225  0.042323  0
# 498    320  1.041416  0
# 499    375  3.626883  1
#
# [500 rows x 3 columns]

# %%
plt.plot(gpa,toeic,'o')
plt.plot(gpa[y==1],toeic[y==1],'o')
