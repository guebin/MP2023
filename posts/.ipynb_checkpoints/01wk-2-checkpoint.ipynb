# %% [raw]
# ---
# title: "01wk-02: 캐글자료 다운로드"
# author: "최규빈"
# date: "09/04/2023"
# ---

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/home/cgb2/Dropbox/07_lectures/2023-09-MP2023/posts"

# %%
# !kaggle competitions download -c bike-sharing-demand
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/cgb2/Dropbox/07_lectures/2023-09-MP2023/posts/kaggle.json'
# Downloading bike-sharing-demand.zip to /home/cgb2/Dropbox/07_lectures/2023-09-MP2023/posts
# 100%|█████████████████████████████████████████| 189k/189k [00:00<00:00, 366kB/s]
# 100%|█████████████████████████████████████████| 189k/189k [00:00<00:00, 366kB/s]

# %%
# !unzip bike-sharing-demand.zip -d ./data
# Out:
# Archive:  bike-sharing-demand.zip
#   inflating: ./data/sampleSubmission.csv
#   inflating: ./data/test.csv
#   inflating: ./data/train.csv

# %%
# !rm bike-sharing-demand.zip

# %%
# !ls ./data
# Out:
# sampleSubmission.csv  test.csv	train.csv

# %%
import pandas as pd

# %%
pd.read_csv('./data/train.csv')
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 0      14.395        81     0.0000       3          13     16
# 1      13.635        80     0.0000       8          32     40
# 2      13.635        80     0.0000       5          27     32
# 3      14.395        75     0.0000       3          10     13
# 4      14.395        75     0.0000       0           1      1
# ...       ...       ...        ...     ...         ...    ...
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88
#
# [10886 rows x 12 columns]

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
train_data = TabularDataset('./data/train.csv')
test_data = TabularDataset('./data/test.csv')

# %%
train_data.drop(['casual','registered'],axis=1)
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  count
# 0      14.395        81     0.0000     16
# 1      13.635        80     0.0000     40
# 2      13.635        80     0.0000     32
# 3      14.395        75     0.0000     13
# 4      14.395        75     0.0000      1
# ...       ...       ...        ...    ...
# 10881  19.695        50    26.0027    336
# 10882  17.425        57    15.0013    241
# 10883  15.910        61    15.0013    168
# 10884  17.425        61     6.0032    129
# 10885  16.665        66     8.9981     88
#
# [10886 rows x 10 columns]

# %%
test_data
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-20 00:00:00       1        0           1        1  10.66
# 1     2011-01-20 01:00:00       1        0           1        1  10.66
# 2     2011-01-20 02:00:00       1        0           1        1  10.66
# 3     2011-01-20 03:00:00       1        0           1        1  10.66
# 4     2011-01-20 04:00:00       1        0           1        1  10.66
# ...                   ...     ...      ...         ...      ...    ...
# 6488  2012-12-31 19:00:00       1        0           1        2  10.66
# 6489  2012-12-31 20:00:00       1        0           1        2  10.66
# 6490  2012-12-31 21:00:00       1        0           1        1  10.66
# 6491  2012-12-31 22:00:00       1        0           1        1  10.66
# 6492  2012-12-31 23:00:00       1        0           1        1  10.66
#
#        atemp  humidity  windspeed
# 0     11.365        56    26.0027
# 1     13.635        56     0.0000
# 2     13.635        56     0.0000
# 3     12.880        56    11.0014
# 4     12.880        56    11.0014
# ...      ...       ...        ...
# 6488  12.880        60    11.0014
# 6489  12.880        60    11.0014
# 6490  12.880        60    11.0014
# 6491  13.635        56     8.9981
# 6492  13.635        65     8.9981
#
# [6493 rows x 9 columns]

# %%
predictor = TabularPredictor(label='count',problem_type='regression',path='./output')
predictor.fit(train_data)

# 테스트 데이터에 대한 예측
predictions = predictor.predict(test_data)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="./output"
# Beginning AutoGluon training ...
# AutoGluon will save models to "./output/"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #26~22.04.1-Ubuntu SMP PREEMPT_DYNAMIC Thu Jul 13 16:27:29 UTC 2
# Disk Space Avail:   317.28 GB / 490.57 GB (64.7%)
# Train Data Rows:    10886
# Train Data Columns: 11
# Label Column: count
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    124634.57 MB
# 	Train Data (Original)  Memory Usage: 1.7 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])                        : 7 | ['season', 'holiday', 'workingday', 'weather', 'humidity', ...]
# 		('object', ['datetime_as_object']) : 1 | ['datetime']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])                  : 5 | ['season', 'weather', 'humidity', 'casual', 'registered']
# 		('int', ['bool'])            : 2 | ['holiday', 'workingday']
# 		('int', ['datetime_as_int']) : 5 | ['datetime', 'datetime.year', 'datetime.month', 'datetime.day', 'datetime.dayofweek']
# 	0.0s = Fit runtime
# 	11 features in original data used to generate 15 features in processed data.
# 	Train Data (Processed) Memory Usage: 1.15 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.05s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 9797, Val Rows: 1089
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-109.9845	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-92.5189	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's rmse: 5.01587
# [2000]	valid_set's rmse: 4.47265
# [3000]	valid_set's rmse: 4.30083
# [4000]	valid_set's rmse: 4.21377
# [5000]	valid_set's rmse: 4.15973
# [6000]	valid_set's rmse: 4.11879
# [7000]	valid_set's rmse: 4.08715
# [8000]	valid_set's rmse: 4.06524
# [9000]	valid_set's rmse: 4.05637
# [10000]	valid_set's rmse: 4.04667
# 	-4.0462	 = Validation score   (-root_mean_squared_error)
# 	5.32s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: LightGBM ...
# 	-2.7689	 = Validation score   (-root_mean_squared_error)
# 	0.52s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-2.6593	 = Validation score   (-root_mean_squared_error)
# 	0.91s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-2.3869	 = Validation score   (-root_mean_squared_error)
# 	8.65s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-2.4677	 = Validation score   (-root_mean_squared_error)
# 	0.46s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-3.7046	 = Validation score   (-root_mean_squared_error)
# 	5.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-3.7605	 = Validation score   (-root_mean_squared_error)
# 	0.24s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-9.0841	 = Validation score   (-root_mean_squared_error)
# 	10.66s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	-3.028	 = Validation score   (-root_mean_squared_error)
# 	1.19s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-1.4176	 = Validation score   (-root_mean_squared_error)
# 	0.22s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 34.09s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("./output/")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/autogluon/features/generators/abstract.py:338, in AbstractFeatureGenerator.transform(self, X)
#     335     if list(X.columns) != self.features_in:
#     336         # It comes at a cost when making a copy of the DataFrame,
#     337         # therefore, try avoid copying by checking the expected features first.
# --> 338         X = X[self.features_in]
#     339 except KeyError:
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/pandas/core/indexes/base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['casual', 'registered'] not in index"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 5
#       2 predictor.fit(train_data)
#       4 # 테스트 데이터에 대한 예측
# ----> 5 predictions = predictor.predict(test_data)
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/autogluon/tabular/predictor/predictor.py:1579, in TabularPredictor.predict(self, data, model, as_pandas, transform_features, decision_threshold)
#    1577 if decision_threshold is None:
#    1578     decision_threshold = self.decision_threshold
# -> 1579 return self._learner.predict(X=data, model=model, as_pandas=as_pandas, transform_features=transform_features, decision_threshold=decision_threshold)
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/autogluon/tabular/learner/abstract_learner.py:208, in AbstractTabularLearner.predict(self, X, model, as_pandas, inverse_transform, transform_features, decision_threshold)
#     206     decision_threshold = 0.5
#     207 X_index = copy.deepcopy(X.index) if as_pandas else None
# --> 208 y_pred_proba = self.predict_proba(
#     209     X=X, model=model, as_pandas=False, as_multiclass=False, inverse_transform=False, transform_features=transform_features
#     210 )
#     211 problem_type = self.label_cleaner.problem_type_transform or self.problem_type
#     212 y_pred = get_pred_from_proba(y_pred_proba=y_pred_proba, problem_type=problem_type, decision_threshold=decision_threshold)
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/autogluon/tabular/learner/abstract_learner.py:188, in AbstractTabularLearner.predict_proba(self, X, model, as_pandas, as_multiclass, inverse_transform, transform_features)
#     186 else:
#     187     if transform_features:
# --> 188         X = self.transform_features(X)
#     189     y_pred_proba = self.load_trainer().predict_proba(X, model=model)
#     190 y_pred_proba = self._post_process_predict_proba(
#     191     y_pred_proba=y_pred_proba, as_pandas=as_pandas, index=X_index, as_multiclass=as_multiclass, inverse_transform=inverse_transform
#     192 )
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/autogluon/tabular/learner/abstract_learner.py:462, in AbstractTabularLearner.transform_features(self, X)
#     460 def transform_features(self, X):
#     461     for feature_generator in self.feature_generators:
# --> 462         X = feature_generator.transform(X)
#     463     return X
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/autogluon/features/generators/abstract.py:344, in AbstractFeatureGenerator.transform(self, X)
#     342         if col not in X.columns:
#     343             missing_cols.append(col)
# --> 344     raise KeyError(
#     345         f"{len(missing_cols)} required columns are missing from the provided dataset to transform using {self.__class__.__name__}. "
#     346         f"{len(missing_cols)} missing columns: {missing_cols} | "
#     347         f"{len(list(X.columns))} available columns: {list(X.columns)}"
#     348     )
#     349 if self._pre_astype_generator:
#     350     X = self._pre_astype_generator.transform(X)
#
# KeyError: "2 required columns are missing from the provided dataset to transform using AutoMLPipelineFeatureGenerator. 2 missing columns: ['casual', 'registered'] | 9 available columns: ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed']"

# %%
predictor.evaluate(test_data, silent=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/autogluon/features/generators/abstract.py:338, in AbstractFeatureGenerator.transform(self, X)
#     335     if list(X.columns) != self.features_in:
#     336         # It comes at a cost when making a copy of the DataFrame,
#     337         # therefore, try avoid copying by checking the expected features first.
# --> 338         X = X[self.features_in]
#     339 except KeyError:
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/pandas/core/indexes/base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['casual', 'registered'] not in index"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 predictor.evaluate(test_data, silent=True)
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/autogluon/tabular/predictor/predictor.py:1719, in TabularPredictor.evaluate(self, data, model, decision_threshold, silent, auxiliary_metrics, detailed_report)
#    1717     y_pred = self.predict_proba(data=data, model=model)
#    1718 else:
# -> 1719     y_pred = self.predict(data=data, model=model)
#    1720 if self.sample_weight is not None and self.weight_evaluation and self.sample_weight in data:
#    1721     sample_weight = data[self.sample_weight]
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/autogluon/tabular/predictor/predictor.py:1579, in TabularPredictor.predict(self, data, model, as_pandas, transform_features, decision_threshold)
#    1577 if decision_threshold is None:
#    1578     decision_threshold = self.decision_threshold
# -> 1579 return self._learner.predict(X=data, model=model, as_pandas=as_pandas, transform_features=transform_features, decision_threshold=decision_threshold)
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/autogluon/tabular/learner/abstract_learner.py:208, in AbstractTabularLearner.predict(self, X, model, as_pandas, inverse_transform, transform_features, decision_threshold)
#     206     decision_threshold = 0.5
#     207 X_index = copy.deepcopy(X.index) if as_pandas else None
# --> 208 y_pred_proba = self.predict_proba(
#     209     X=X, model=model, as_pandas=False, as_multiclass=False, inverse_transform=False, transform_features=transform_features
#     210 )
#     211 problem_type = self.label_cleaner.problem_type_transform or self.problem_type
#     212 y_pred = get_pred_from_proba(y_pred_proba=y_pred_proba, problem_type=problem_type, decision_threshold=decision_threshold)
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/autogluon/tabular/learner/abstract_learner.py:188, in AbstractTabularLearner.predict_proba(self, X, model, as_pandas, as_multiclass, inverse_transform, transform_features)
#     186 else:
#     187     if transform_features:
# --> 188         X = self.transform_features(X)
#     189     y_pred_proba = self.load_trainer().predict_proba(X, model=model)
#     190 y_pred_proba = self._post_process_predict_proba(
#     191     y_pred_proba=y_pred_proba, as_pandas=as_pandas, index=X_index, as_multiclass=as_multiclass, inverse_transform=inverse_transform
#     192 )
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/autogluon/tabular/learner/abstract_learner.py:462, in AbstractTabularLearner.transform_features(self, X)
#     460 def transform_features(self, X):
#     461     for feature_generator in self.feature_generators:
# --> 462         X = feature_generator.transform(X)
#     463     return X
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/autogluon/features/generators/abstract.py:344, in AbstractFeatureGenerator.transform(self, X)
#     342         if col not in X.columns:
#     343             missing_cols.append(col)
# --> 344     raise KeyError(
#     345         f"{len(missing_cols)} required columns are missing from the provided dataset to transform using {self.__class__.__name__}. "
#     346         f"{len(missing_cols)} missing columns: {missing_cols} | "
#     347         f"{len(list(X.columns))} available columns: {list(X.columns)}"
#     348     )
#     349 if self._pre_astype_generator:
#     350     X = self._pre_astype_generator.transform(X)
#
# KeyError: "2 required columns are missing from the provided dataset to transform using AutoMLPipelineFeatureGenerator. 2 missing columns: ['casual', 'registered'] | 9 available columns: ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed']"
