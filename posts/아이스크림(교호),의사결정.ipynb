# %% [raw]
# ---
# title: "07wk-028: 아이스크림(초코/바닐라)2, 교호작용"
# author: "최규빈"
# date: "10/16/2023"
# bibliography: ref.bib
# draft: true
# ---

# %% [markdown]
# # 1. 강의영상

# %% [markdown]
# {{<video ???? >}}

# %% [markdown]
# # 2. Imports

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import sklearn.linear_model 
import sklearn.tree
import sklearn.model_selection
import graphviz

# %% [markdown]
# # 3. Data

# %%
np.random.seed(43052)
temp = pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/posts/temp.csv').iloc[:,3].to_numpy()[:100]
temp.sort()
choco = 40 + temp * 2.0 + np.random.randn(100)*3
vanilla = 20 + temp * 5.0 + np.random.randn(100)*3

# %%
plt.plot(temp,choco,'o',label='choco')
plt.plot(temp,vanilla,'o',label='vanilla')
plt.legend()

# %% [markdown]
# - 초코보다 바닐라맛이 기온의 영향을 많이 받아보임

# %%
df1 = pd.DataFrame({'temp':temp,'sales':choco}).assign(type='choco')
df2 = pd.DataFrame({'temp':temp,'sales':vanilla}).assign(type='vanilla')
df = pd.concat([df1,df2])
df
# Out:
#     temp      sales     type
# 0   -4.1  32.950261    choco
# 1   -3.7  35.852524    choco
# 2   -3.0  37.428335    choco
# 3   -1.3  38.323681    choco
# 4   -0.5  39.713362    choco
# ..   ...        ...      ...
# 95  12.4  79.708075  vanilla
# 96  13.4  89.300464  vanilla
# 97  14.7  96.596568  vanilla
# 98  15.0  96.213140  vanilla
# 99  15.2  95.595252  vanilla
#
# [200 rows x 3 columns]

# %% [markdown]
# # 5. 분석2

# %% [markdown]
# `-` 모형을 아래와 같이 본다.

# %% [markdown]
# - ${\bf X}$: `temp`, `type`, `temp` $\times$ `type`
# - ${\bf y}$: `sales`

# %% [markdown]
# > Note: 초코/바닐라에 대한 절편차이는 `type`로, 초코/바닐라에 대한 기울기 차이는 `temp`$\times$`type`로 표현한다.

# %%
# step1
X = pd.get_dummies(df[['temp','type']])
y = df['sales']
# step2 
predictr = sklearn.tree.DecisionTreeRegressor()
# step3
predictr.fit(X,y)
# step4 
yhat = predictr.predict(X)

# %%
df['sales_hat'] = yhat
df
# Out:
#     temp      sales     type  sales_hat
# 0   -4.1  32.950261    choco  32.950261
# 1   -3.7  35.852524    choco  35.852524
# 2   -3.0  37.428335    choco  37.428335
# 3   -1.3  38.323681    choco  38.323681
# 4   -0.5  39.713362    choco  39.713362
# ..   ...        ...      ...        ...
# 95  12.4  79.708075  vanilla  79.708075
# 96  13.4  89.300464  vanilla  89.300464
# 97  14.7  96.596568  vanilla  96.596568
# 98  15.0  96.213140  vanilla  96.213140
# 99  15.2  95.595252  vanilla  95.595252
#
# [200 rows x 4 columns]

# %%
plt.plot(df.temp,df.sales,'o')
plt.plot(df.temp,df.sales_hat,'x')

# %% [markdown]
# - 느낌이 싸함..

# %%
print(sklearn.tree.export_text(predictr,feature_names=X.columns))
# Out:
# |--- temp <= 5.05
# |   |--- type_vanilla <= 0.50
# |   |   |--- temp <= 1.75
# |   |   |   |--- temp <= 0.80
# |   |   |   |   |--- temp <= -3.90
# |   |   |   |   |   |--- value: [32.95]
# |   |   |   |   |--- temp >  -3.90
# |   |   |   |   |   |--- temp <= 0.55
# |   |   |   |   |   |   |--- temp <= 0.00
# |   |   |   |   |   |   |   |--- temp <= -0.90
# |   |   |   |   |   |   |   |   |--- temp <= -3.35
# |   |   |   |   |   |   |   |   |   |--- value: [35.85]
# |   |   |   |   |   |   |   |   |--- temp >  -3.35
# |   |   |   |   |   |   |   |   |   |--- temp <= -2.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [37.43]
# |   |   |   |   |   |   |   |   |   |--- temp >  -2.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [38.32]
# |   |   |   |   |   |   |   |--- temp >  -0.90
# |   |   |   |   |   |   |   |   |--- temp <= -0.40
# |   |   |   |   |   |   |   |   |   |--- value: [39.71]
# |   |   |   |   |   |   |   |   |--- temp >  -0.40
# |   |   |   |   |   |   |   |   |   |--- value: [40.47]
# |   |   |   |   |   |   |--- temp >  0.00
# |   |   |   |   |   |   |   |--- temp <= 0.35
# |   |   |   |   |   |   |   |   |--- value: [35.61]
# |   |   |   |   |   |   |   |--- temp >  0.35
# |   |   |   |   |   |   |   |   |--- value: [35.84]
# |   |   |   |   |   |--- temp >  0.55
# |   |   |   |   |   |   |--- value: [39.18]
# |   |   |   |--- temp >  0.80
# |   |   |   |   |--- temp <= 1.45
# |   |   |   |   |   |--- temp <= 1.30
# |   |   |   |   |   |   |--- temp <= 1.10
# |   |   |   |   |   |   |   |--- temp <= 0.95
# |   |   |   |   |   |   |   |   |--- value: [41.23]
# |   |   |   |   |   |   |   |--- temp >  0.95
# |   |   |   |   |   |   |   |   |--- value: [44.13]
# |   |   |   |   |   |   |--- temp >  1.10
# |   |   |   |   |   |   |   |--- value: [37.75]
# |   |   |   |   |   |--- temp >  1.30
# |   |   |   |   |   |   |--- value: [44.73]
# |   |   |   |   |--- temp >  1.45
# |   |   |   |   |   |--- value: [39.56]
# |   |   |--- temp >  1.75
# |   |   |   |--- temp <= 2.75
# |   |   |   |   |--- temp <= 2.15
# |   |   |   |   |   |--- value: [44.06]
# |   |   |   |   |--- temp >  2.15
# |   |   |   |   |   |--- temp <= 2.40
# |   |   |   |   |   |   |--- value: [51.27]
# |   |   |   |   |   |--- temp >  2.40
# |   |   |   |   |   |   |--- temp <= 2.55
# |   |   |   |   |   |   |   |--- value: [45.24]
# |   |   |   |   |   |   |--- temp >  2.55
# |   |   |   |   |   |   |   |--- value: [45.71]
# |   |   |   |--- temp >  2.75
# |   |   |   |   |--- temp <= 4.30
# |   |   |   |   |   |--- temp <= 3.75
# |   |   |   |   |   |   |--- temp <= 3.35
# |   |   |   |   |   |   |   |--- temp <= 3.05
# |   |   |   |   |   |   |   |   |--- value: [48.11]
# |   |   |   |   |   |   |   |--- temp >  3.05
# |   |   |   |   |   |   |   |   |--- value: [49.15]
# |   |   |   |   |   |   |--- temp >  3.35
# |   |   |   |   |   |   |   |--- temp <= 3.55
# |   |   |   |   |   |   |   |   |--- value: [46.80]
# |   |   |   |   |   |   |   |--- temp >  3.55
# |   |   |   |   |   |   |   |   |--- temp <= 3.65
# |   |   |   |   |   |   |   |   |   |--- value: [49.65]
# |   |   |   |   |   |   |   |   |--- temp >  3.65
# |   |   |   |   |   |   |   |   |   |--- value: [46.90]
# |   |   |   |   |   |--- temp >  3.75
# |   |   |   |   |   |   |--- temp <= 4.00
# |   |   |   |   |   |   |   |--- value: [51.00]
# |   |   |   |   |   |   |--- temp >  4.00
# |   |   |   |   |   |   |   |--- value: [49.03]
# |   |   |   |   |--- temp >  4.30
# |   |   |   |   |   |--- temp <= 4.45
# |   |   |   |   |   |   |--- value: [43.76]
# |   |   |   |   |   |--- temp >  4.45
# |   |   |   |   |   |   |--- temp <= 4.55
# |   |   |   |   |   |   |   |--- value: [49.48]
# |   |   |   |   |   |   |--- temp >  4.55
# |   |   |   |   |   |   |   |--- temp <= 4.75
# |   |   |   |   |   |   |   |   |--- value: [48.30]
# |   |   |   |   |   |   |   |--- temp >  4.75
# |   |   |   |   |   |   |   |   |--- temp <= 4.95
# |   |   |   |   |   |   |   |   |   |--- value: [47.10]
# |   |   |   |   |   |   |   |   |--- temp >  4.95
# |   |   |   |   |   |   |   |   |   |--- value: [48.01]
# |   |--- type_vanilla >  0.50
# |   |   |--- temp <= 1.45
# |   |   |   |--- temp <= -0.90
# |   |   |   |   |--- temp <= -3.35
# |   |   |   |   |   |--- temp <= -3.90
# |   |   |   |   |   |   |--- value: [-1.25]
# |   |   |   |   |   |--- temp >  -3.90
# |   |   |   |   |   |   |--- value: [-3.24]
# |   |   |   |   |--- temp >  -3.35
# |   |   |   |   |   |--- temp <= -2.15
# |   |   |   |   |   |   |--- value: [5.34]
# |   |   |   |   |   |--- temp >  -2.15
# |   |   |   |   |   |   |--- value: [6.35]
# |   |   |   |--- temp >  -0.90
# |   |   |   |   |--- temp <= 0.80
# |   |   |   |   |   |--- temp <= 0.35
# |   |   |   |   |   |   |--- temp <= -0.40
# |   |   |   |   |   |   |   |--- value: [19.86]
# |   |   |   |   |   |   |--- temp >  -0.40
# |   |   |   |   |   |   |   |--- temp <= 0.00
# |   |   |   |   |   |   |   |   |--- value: [23.01]
# |   |   |   |   |   |   |   |--- temp >  0.00
# |   |   |   |   |   |   |   |   |--- value: [19.88]
# |   |   |   |   |   |--- temp >  0.35
# |   |   |   |   |   |   |--- temp <= 0.55
# |   |   |   |   |   |   |   |--- value: [22.55]
# |   |   |   |   |   |   |--- temp >  0.55
# |   |   |   |   |   |   |   |--- value: [23.32]
# |   |   |   |   |--- temp >  0.80
# |   |   |   |   |   |--- temp <= 1.10
# |   |   |   |   |   |   |--- temp <= 0.95
# |   |   |   |   |   |   |   |--- value: [26.94]
# |   |   |   |   |   |   |--- temp >  0.95
# |   |   |   |   |   |   |   |--- value: [29.62]
# |   |   |   |   |   |--- temp >  1.10
# |   |   |   |   |   |   |--- temp <= 1.30
# |   |   |   |   |   |   |   |--- value: [22.00]
# |   |   |   |   |   |   |--- temp >  1.30
# |   |   |   |   |   |   |   |--- value: [25.44]
# |   |   |--- temp >  1.45
# |   |   |   |--- temp <= 3.65
# |   |   |   |   |--- temp <= 2.40
# |   |   |   |   |   |--- temp <= 1.75
# |   |   |   |   |   |   |--- value: [32.32]
# |   |   |   |   |   |--- temp >  1.75
# |   |   |   |   |   |   |--- temp <= 2.15
# |   |   |   |   |   |   |   |--- value: [29.85]
# |   |   |   |   |   |   |--- temp >  2.15
# |   |   |   |   |   |   |   |--- value: [29.33]
# |   |   |   |   |--- temp >  2.40
# |   |   |   |   |   |--- temp <= 3.05
# |   |   |   |   |   |   |--- temp <= 2.55
# |   |   |   |   |   |   |   |--- value: [33.19]
# |   |   |   |   |   |   |--- temp >  2.55
# |   |   |   |   |   |   |   |--- temp <= 2.75
# |   |   |   |   |   |   |   |   |--- value: [34.82]
# |   |   |   |   |   |   |   |--- temp >  2.75
# |   |   |   |   |   |   |   |   |--- value: [32.86]
# |   |   |   |   |   |--- temp >  3.05
# |   |   |   |   |   |   |--- temp <= 3.55
# |   |   |   |   |   |   |   |--- temp <= 3.35
# |   |   |   |   |   |   |   |   |--- value: [37.10]
# |   |   |   |   |   |   |   |--- temp >  3.35
# |   |   |   |   |   |   |   |   |--- value: [36.89]
# |   |   |   |   |   |   |--- temp >  3.55
# |   |   |   |   |   |   |   |--- value: [36.30]
# |   |   |   |--- temp >  3.65
# |   |   |   |   |--- temp <= 4.95
# |   |   |   |   |   |--- temp <= 4.00
# |   |   |   |   |   |   |--- temp <= 3.75
# |   |   |   |   |   |   |   |--- value: [40.55]
# |   |   |   |   |   |   |--- temp >  3.75
# |   |   |   |   |   |   |   |--- value: [41.06]
# |   |   |   |   |   |--- temp >  4.00
# |   |   |   |   |   |   |--- temp <= 4.75
# |   |   |   |   |   |   |   |--- temp <= 4.55
# |   |   |   |   |   |   |   |   |--- temp <= 4.45
# |   |   |   |   |   |   |   |   |   |--- temp <= 4.30
# |   |   |   |   |   |   |   |   |   |   |--- value: [44.67]
# |   |   |   |   |   |   |   |   |   |--- temp >  4.30
# |   |   |   |   |   |   |   |   |   |   |--- value: [43.12]
# |   |   |   |   |   |   |   |   |--- temp >  4.45
# |   |   |   |   |   |   |   |   |   |--- value: [44.50]
# |   |   |   |   |   |   |   |--- temp >  4.55
# |   |   |   |   |   |   |   |   |--- value: [45.49]
# |   |   |   |   |   |   |--- temp >  4.75
# |   |   |   |   |   |   |   |--- value: [42.49]
# |   |   |   |   |--- temp >  4.95
# |   |   |   |   |   |--- value: [47.03]
# |--- temp >  5.05
# |   |--- temp <= 9.85
# |   |   |--- temp <= 7.85
# |   |   |   |--- temp <= 6.60
# |   |   |   |   |--- type_choco <= 0.50
# |   |   |   |   |   |--- temp <= 6.20
# |   |   |   |   |   |   |--- temp <= 5.75
# |   |   |   |   |   |   |   |--- temp <= 5.35
# |   |   |   |   |   |   |   |   |--- value: [48.16]
# |   |   |   |   |   |   |   |--- temp >  5.35
# |   |   |   |   |   |   |   |   |--- value: [48.59]
# |   |   |   |   |   |   |--- temp >  5.75
# |   |   |   |   |   |   |   |--- temp <= 6.05
# |   |   |   |   |   |   |   |   |--- temp <= 5.95
# |   |   |   |   |   |   |   |   |   |--- value: [49.93]
# |   |   |   |   |   |   |   |   |--- temp >  5.95
# |   |   |   |   |   |   |   |   |   |--- value: [50.42]
# |   |   |   |   |   |   |   |--- temp >  6.05
# |   |   |   |   |   |   |   |   |--- value: [49.21]
# |   |   |   |   |   |--- temp >  6.20
# |   |   |   |   |   |   |--- temp <= 6.35
# |   |   |   |   |   |   |   |--- value: [52.91]
# |   |   |   |   |   |   |--- temp >  6.35
# |   |   |   |   |   |   |   |--- temp <= 6.45
# |   |   |   |   |   |   |   |   |--- value: [51.26]
# |   |   |   |   |   |   |   |--- temp >  6.45
# |   |   |   |   |   |   |   |   |--- value: [51.44]
# |   |   |   |   |--- type_choco >  0.50
# |   |   |   |   |   |--- temp <= 5.75
# |   |   |   |   |   |   |--- temp <= 5.35
# |   |   |   |   |   |   |   |--- value: [54.00]
# |   |   |   |   |   |   |--- temp >  5.35
# |   |   |   |   |   |   |   |--- value: [53.72]
# |   |   |   |   |   |--- temp >  5.75
# |   |   |   |   |   |   |--- temp <= 5.95
# |   |   |   |   |   |   |   |--- value: [49.35]
# |   |   |   |   |   |   |--- temp >  5.95
# |   |   |   |   |   |   |   |--- temp <= 6.05
# |   |   |   |   |   |   |   |   |--- value: [54.48]
# |   |   |   |   |   |   |   |--- temp >  6.05
# |   |   |   |   |   |   |   |   |--- temp <= 6.45
# |   |   |   |   |   |   |   |   |   |--- temp <= 6.20
# |   |   |   |   |   |   |   |   |   |   |--- value: [50.81]
# |   |   |   |   |   |   |   |   |   |--- temp >  6.20
# |   |   |   |   |   |   |   |   |   |   |--- temp <= 6.35
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [51.73]
# |   |   |   |   |   |   |   |   |   |   |--- temp >  6.35
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [51.19]
# |   |   |   |   |   |   |   |   |--- temp >  6.45
# |   |   |   |   |   |   |   |   |   |--- value: [52.83]
# |   |   |   |--- temp >  6.60
# |   |   |   |   |--- temp <= 7.15
# |   |   |   |   |   |--- temp <= 6.90
# |   |   |   |   |   |   |--- type_vanilla <= 0.50
# |   |   |   |   |   |   |   |--- temp <= 6.75
# |   |   |   |   |   |   |   |   |--- value: [50.88]
# |   |   |   |   |   |   |   |--- temp >  6.75
# |   |   |   |   |   |   |   |   |--- value: [55.03]
# |   |   |   |   |   |   |--- type_vanilla >  0.50
# |   |   |   |   |   |   |   |--- temp <= 6.75
# |   |   |   |   |   |   |   |   |--- value: [56.47]
# |   |   |   |   |   |   |   |--- temp >  6.75
# |   |   |   |   |   |   |   |   |--- value: [54.90]
# |   |   |   |   |   |--- temp >  6.90
# |   |   |   |   |   |   |--- temp <= 7.05
# |   |   |   |   |   |   |   |--- type_choco <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [52.22]
# |   |   |   |   |   |   |   |--- type_choco >  0.50
# |   |   |   |   |   |   |   |   |--- value: [53.48]
# |   |   |   |   |   |   |--- temp >  7.05
# |   |   |   |   |   |   |   |--- type_choco <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [52.92]
# |   |   |   |   |   |   |   |--- type_choco >  0.50
# |   |   |   |   |   |   |   |   |--- value: [50.39]
# |   |   |   |   |--- temp >  7.15
# |   |   |   |   |   |--- temp <= 7.30
# |   |   |   |   |   |   |--- type_choco <= 0.50
# |   |   |   |   |   |   |   |--- value: [57.66]
# |   |   |   |   |   |   |--- type_choco >  0.50
# |   |   |   |   |   |   |   |--- value: [59.63]
# |   |   |   |   |   |--- temp >  7.30
# |   |   |   |   |   |   |--- temp <= 7.55
# |   |   |   |   |   |   |   |--- type_vanilla <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [53.72]
# |   |   |   |   |   |   |   |--- type_vanilla >  0.50
# |   |   |   |   |   |   |   |   |--- value: [57.31]
# |   |   |   |   |   |   |--- temp >  7.55
# |   |   |   |   |   |   |   |--- type_vanilla <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [54.85]
# |   |   |   |   |   |   |   |--- type_vanilla >  0.50
# |   |   |   |   |   |   |   |   |--- value: [53.52]
# |   |   |--- temp >  7.85
# |   |   |   |--- type_vanilla <= 0.50
# |   |   |   |   |--- temp <= 8.45
# |   |   |   |   |   |--- temp <= 8.20
# |   |   |   |   |   |   |--- temp <= 8.05
# |   |   |   |   |   |   |   |--- value: [57.87]
# |   |   |   |   |   |   |--- temp >  8.05
# |   |   |   |   |   |   |   |--- value: [56.28]
# |   |   |   |   |   |--- temp >  8.20
# |   |   |   |   |   |   |--- temp <= 8.35
# |   |   |   |   |   |   |   |--- value: [53.40]
# |   |   |   |   |   |   |--- temp >  8.35
# |   |   |   |   |   |   |   |--- value: [54.51]
# |   |   |   |   |--- temp >  8.45
# |   |   |   |   |   |--- temp <= 8.85
# |   |   |   |   |   |   |--- temp <= 8.65
# |   |   |   |   |   |   |   |--- value: [59.21]
# |   |   |   |   |   |   |--- temp >  8.65
# |   |   |   |   |   |   |   |--- value: [64.16]
# |   |   |   |   |   |--- temp >  8.85
# |   |   |   |   |   |   |--- temp <= 9.45
# |   |   |   |   |   |   |   |--- temp <= 9.00
# |   |   |   |   |   |   |   |   |--- value: [54.35]
# |   |   |   |   |   |   |   |--- temp >  9.00
# |   |   |   |   |   |   |   |   |--- temp <= 9.25
# |   |   |   |   |   |   |   |   |   |--- temp <= 9.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [57.36]
# |   |   |   |   |   |   |   |   |   |--- temp >  9.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [56.89]
# |   |   |   |   |   |   |   |   |--- temp >  9.25
# |   |   |   |   |   |   |   |   |   |--- temp <= 9.35
# |   |   |   |   |   |   |   |   |   |   |--- value: [53.61]
# |   |   |   |   |   |   |   |   |   |--- temp >  9.35
# |   |   |   |   |   |   |   |   |   |   |--- value: [56.09]
# |   |   |   |   |   |   |--- temp >  9.45
# |   |   |   |   |   |   |   |--- temp <= 9.75
# |   |   |   |   |   |   |   |   |--- temp <= 9.65
# |   |   |   |   |   |   |   |   |   |--- temp <= 9.55
# |   |   |   |   |   |   |   |   |   |   |--- value: [57.24]
# |   |   |   |   |   |   |   |   |   |--- temp >  9.55
# |   |   |   |   |   |   |   |   |   |   |--- value: [59.44]
# |   |   |   |   |   |   |   |   |--- temp >  9.65
# |   |   |   |   |   |   |   |   |   |--- value: [53.90]
# |   |   |   |   |   |   |   |--- temp >  9.75
# |   |   |   |   |   |   |   |   |--- value: [60.38]
# |   |   |   |--- type_vanilla >  0.50
# |   |   |   |   |--- temp <= 8.85
# |   |   |   |   |   |--- temp <= 8.05
# |   |   |   |   |   |   |--- value: [57.10]
# |   |   |   |   |   |--- temp >  8.05
# |   |   |   |   |   |   |--- temp <= 8.20
# |   |   |   |   |   |   |   |--- value: [67.29]
# |   |   |   |   |   |   |--- temp >  8.20
# |   |   |   |   |   |   |   |--- temp <= 8.65
# |   |   |   |   |   |   |   |   |--- temp <= 8.45
# |   |   |   |   |   |   |   |   |   |--- temp <= 8.35
# |   |   |   |   |   |   |   |   |   |   |--- value: [60.36]
# |   |   |   |   |   |   |   |   |   |--- temp >  8.35
# |   |   |   |   |   |   |   |   |   |   |--- value: [60.79]
# |   |   |   |   |   |   |   |   |--- temp >  8.45
# |   |   |   |   |   |   |   |   |   |--- value: [62.00]
# |   |   |   |   |   |   |   |--- temp >  8.65
# |   |   |   |   |   |   |   |   |--- value: [64.27]
# |   |   |   |   |--- temp >  8.85
# |   |   |   |   |   |--- temp <= 9.35
# |   |   |   |   |   |   |--- temp <= 9.25
# |   |   |   |   |   |   |   |--- temp <= 9.00
# |   |   |   |   |   |   |   |   |--- value: [67.12]
# |   |   |   |   |   |   |   |--- temp >  9.00
# |   |   |   |   |   |   |   |   |--- temp <= 9.15
# |   |   |   |   |   |   |   |   |   |--- value: [66.70]
# |   |   |   |   |   |   |   |   |--- temp >  9.15
# |   |   |   |   |   |   |   |   |   |--- value: [66.61]
# |   |   |   |   |   |   |--- temp >  9.25
# |   |   |   |   |   |   |   |--- value: [69.63]
# |   |   |   |   |   |--- temp >  9.35
# |   |   |   |   |   |   |--- temp <= 9.65
# |   |   |   |   |   |   |   |--- temp <= 9.45
# |   |   |   |   |   |   |   |   |--- value: [64.61]
# |   |   |   |   |   |   |   |--- temp >  9.45
# |   |   |   |   |   |   |   |   |--- temp <= 9.55
# |   |   |   |   |   |   |   |   |   |--- value: [66.20]
# |   |   |   |   |   |   |   |   |--- temp >  9.55
# |   |   |   |   |   |   |   |   |   |--- value: [65.04]
# |   |   |   |   |   |   |--- temp >  9.65
# |   |   |   |   |   |   |   |--- temp <= 9.75
# |   |   |   |   |   |   |   |   |--- value: [68.56]
# |   |   |   |   |   |   |   |--- temp >  9.75
# |   |   |   |   |   |   |   |   |--- value: [67.28]
# |   |--- temp >  9.85
# |   |   |--- type_choco <= 0.50
# |   |   |   |--- temp <= 12.90
# |   |   |   |   |--- temp <= 11.65
# |   |   |   |   |   |--- temp <= 10.45
# |   |   |   |   |   |   |--- temp <= 10.25
# |   |   |   |   |   |   |   |--- temp <= 10.05
# |   |   |   |   |   |   |   |   |--- value: [72.31]
# |   |   |   |   |   |   |   |--- temp >  10.05
# |   |   |   |   |   |   |   |   |--- value: [74.24]
# |   |   |   |   |   |   |--- temp >  10.25
# |   |   |   |   |   |   |   |--- value: [72.25]
# |   |   |   |   |   |--- temp >  10.45
# |   |   |   |   |   |   |--- temp <= 10.70
# |   |   |   |   |   |   |   |--- value: [74.89]
# |   |   |   |   |   |   |--- temp >  10.70
# |   |   |   |   |   |   |   |--- temp <= 11.00
# |   |   |   |   |   |   |   |   |--- value: [74.35]
# |   |   |   |   |   |   |   |--- temp >  11.00
# |   |   |   |   |   |   |   |   |--- value: [74.95]
# |   |   |   |   |--- temp >  11.65
# |   |   |   |   |   |--- temp <= 12.25
# |   |   |   |   |   |   |--- value: [81.73]
# |   |   |   |   |   |--- temp >  12.25
# |   |   |   |   |   |   |--- value: [79.71]
# |   |   |   |--- temp >  12.90
# |   |   |   |   |--- temp <= 14.05
# |   |   |   |   |   |--- value: [89.30]
# |   |   |   |   |--- temp >  14.05
# |   |   |   |   |   |--- temp <= 15.10
# |   |   |   |   |   |   |--- temp <= 14.85
# |   |   |   |   |   |   |   |--- value: [96.60]
# |   |   |   |   |   |   |--- temp >  14.85
# |   |   |   |   |   |   |   |--- value: [96.21]
# |   |   |   |   |   |--- temp >  15.10
# |   |   |   |   |   |   |--- value: [95.60]
# |   |   |--- type_choco >  0.50
# |   |   |   |--- temp <= 11.65
# |   |   |   |   |--- temp <= 10.70
# |   |   |   |   |   |--- temp <= 10.05
# |   |   |   |   |   |   |--- value: [57.97]
# |   |   |   |   |   |--- temp >  10.05
# |   |   |   |   |   |   |--- temp <= 10.45
# |   |   |   |   |   |   |   |--- temp <= 10.25
# |   |   |   |   |   |   |   |   |--- value: [60.82]
# |   |   |   |   |   |   |   |--- temp >  10.25
# |   |   |   |   |   |   |   |   |--- value: [60.53]
# |   |   |   |   |   |   |--- temp >  10.45
# |   |   |   |   |   |   |   |--- value: [60.80]
# |   |   |   |   |--- temp >  10.70
# |   |   |   |   |   |--- temp <= 11.00
# |   |   |   |   |   |   |--- value: [62.70]
# |   |   |   |   |   |--- temp >  11.00
# |   |   |   |   |   |   |--- value: [63.43]
# |   |   |   |--- temp >  11.65
# |   |   |   |   |--- temp <= 14.85
# |   |   |   |   |   |--- temp <= 12.25
# |   |   |   |   |   |   |--- value: [65.86]
# |   |   |   |   |   |--- temp >  12.25
# |   |   |   |   |   |   |--- temp <= 14.05
# |   |   |   |   |   |   |   |--- temp <= 12.90
# |   |   |   |   |   |   |   |   |--- value: [68.73]
# |   |   |   |   |   |   |   |--- temp >  12.90
# |   |   |   |   |   |   |   |   |--- value: [68.02]
# |   |   |   |   |   |   |--- temp >  14.05
# |   |   |   |   |   |   |   |--- value: [68.84]
# |   |   |   |   |--- temp >  14.85
# |   |   |   |   |   |--- temp <= 15.10
# |   |   |   |   |   |   |--- value: [73.17]
# |   |   |   |   |   |--- temp >  15.10
# |   |   |   |   |   |   |--- value: [73.96]

# %%
dot_data = sklearn.tree.export_graphviz(predictr, 
                      feature_names=predictr.feature_names_in_,  
#                      class_names=predictr.target_names,  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph.
